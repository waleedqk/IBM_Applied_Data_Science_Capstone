# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlalchemy==1.3.9
# !pip install ipython-sql
# Out:
# Looking in indexes: https://waleedqk%40ibm.com:****@na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-nlp-pypi-virtual/simple, https://waleedqk%40ibm.com:****@na.artifactory.swg-devops.com/artifactory/api/pypi/res-srom-pypi-local/simple, https://waleedqk%40ibm.com:****@na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-ai-foundation-team-pypi-virtual/simple
# Requirement already satisfied: sqlalchemy==1.3.9 in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (1.3.9)
#
# [notice] A new release of pip is available: 23.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Looking in indexes: https://waleedqk%40ibm.com:****@na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-nlp-pypi-virtual/simple, https://waleedqk%40ibm.com:****@na.artifactory.swg-devops.com/artifactory/api/pypi/res-srom-pypi-local/simple, https://waleedqk%40ibm.com:****@na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-ai-foundation-team-pypi-virtual/simple
# Collecting ipython-sql
#   Downloading https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-ai-foundation-team-pypi-virtual/packages/packages/30/8f/9e50fa53ffc371483f9d1b90c1175b706d28a2e978e90a8894035af01905/ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Collecting prettytable (from ipython-sql)
#   Downloading https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-ai-foundation-team-pypi-virtual/packages/packages/25/1e/4c284713b092ec384fad4399452f43f6446ad9aabc9c0b3c3c0920cc53b6/prettytable-3.8.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: ipython in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython-sql) (8.6.0)
# Collecting sqlalchemy>=2.0 (from ipython-sql)
#   Downloading https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-ai-foundation-team-pypi-virtual/packages/packages/4b/dd/8fe0fc21fc4338e7479f1b254a67b5515bd31b85c28925045bc8b0d5a1c3/SQLAlchemy-2.0.20-cp39-cp39-macosx_10_9_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.0 MB/s eta 0:00:00:00:010:01m
# Collecting sqlparse (from ipython-sql)
#   Downloading https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-ai-foundation-team-pypi-virtual/packages/packages/98/5a/66d7c9305baa9f11857f247d4ba761402cea75db6058ff850ed7128957b7/sqlparse-0.4.4-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 675.6 kB/s eta 0:00:0000:01
# Requirement already satisfied: six in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython-sql) (1.16.0)
# Collecting ipython-genutils (from ipython-sql)
#   Downloading https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-ai-foundation-team-pypi-virtual/packages/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting typing-extensions>=4.2.0 (from sqlalchemy>=2.0->ipython-sql)
#   Using cached https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-ai-foundation-team-pypi-virtual/packages/packages/ec/6b/63cc3df74987c36fe26157ee12e09e8f9db4de771e0f3404263117e75b95/typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=2.0->ipython-sql)
#   Downloading https://na.artifactory.swg-devops.com/artifactory/api/pypi/wcp-ai-foundation-team-pypi-virtual/packages/packages/1e/1e/632e55a04d732c8184201238d911207682b119c35cecbb9a573a6c566731/greenlet-2.0.2.tar.gz (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: backcall in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython->ipython-sql) (3.0.32)
# Requirement already satisfied: pygments>=2.4.0 in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython->ipython-sql) (2.13.0)
# Requirement already satisfied: stack-data in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython->ipython-sql) (0.6.0)
# Requirement already satisfied: traitlets>=5 in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython->ipython-sql) (5.5.0)
# Requirement already satisfied: pexpect>4.3 in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: appnope in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from ipython->ipython-sql) (0.1.3)
# Requirement already satisfied: wcwidth in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (2.1.0)
# Requirement already satisfied: pure-eval in /Users/waleedqk@ibm.com/miniconda/envs/ds_py39/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Building wheels for collected packages: greenlet
#   Building wheel for greenlet (setup.py) ... done
#   Created wheel for greenlet: filename=greenlet-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl size=190077 sha256=5e576224e53372e7e26638eaa1a3ea03b3765ce24298c610a8f5315ce17a90fc
#   Stored in directory: /Users/waleedqk@ibm.com/Library/Caches/pip/wheels/55/f8/e4/5081f5a0ee3e9377b06df975ac0f93c7ba2de7fd8127593041
# Successfully built greenlet
# Installing collected packages: ipython-genutils, typing-extensions, sqlparse, prettytable, greenlet, sqlalchemy, ipython-sql
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.9
#     Uninstalling SQLAlchemy-1.3.9:
#       Successfully uninstalled SQLAlchemy-1.3.9
# Successfully installed greenlet-2.0.2 ipython-genutils-0.2.0 ipython-sql-0.5.0 prettytable-3.8.0 sqlalchemy-2.0.20 sqlparse-0.4.4 typing-extensions-4.7.1
#
# [notice] A new release of pip is available: 23.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql

# %%
import csv, sqlite3

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas==1.1.5
# Out:
# [notice] A new release of pip is available: 23.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %% [markdown]
# **Note:This below code is added to remove blank rows from table**

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %sql select distinct LAUNCH_SITE from SPACEXTBL;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS LC-40',), ('VAFB SLC-4E',), ('KSC LC-39A',), ('CCAFS SLC-40',)]

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
# %sql select * from SPACEXTBL where LAUNCH_SITE like 'CCA%' LIMIT 5;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2010-04-06', '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  ('2010-08-12', '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  ('2012-05-22', '07:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  ('2012-08-10', '00:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('2013-01-03', '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %sql select SUM(PAYLOAD_MASS__KG_) as Total_payload from SPACEXTBL where customer = 'NASA (CRS)' ;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(45596,)]

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# %sql select AVG(PAYLOAD_MASS__KG_) as Avg_payload_mass from SPACEXTBL where booster_version ='F9 v1.1';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(2928.4,)]

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
# %sql select MIN(DATE) from SPACEXTBL where Landing_Outcome = 'Success (ground pad)';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2015-12-22',)]

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %sql select DISTINCT(Booster_Version) from SPACEXTBL where Landing_Outcome = 'Success (drone ship)' and (PAYLOAD_MASS__KG_ between 4000 and 6000);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 FT B1022',), ('F9 FT B1026',), ('F9 FT  B1021.2',), ('F9 FT  B1031.2',)]

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
# %sql select count(*) from SPACEXTBL as Total_successful_missions where mission_outcome = 'Success'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(98,)]

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
# %sql select BOOSTER_VERSION from SPACEXTBL where payload_mass__kg_ = (select max(payload_mass__kg_) from SPACEXTBL)
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1051.3',),
#  ('F9 B5 B1056.4',),
#  ('F9 B5 B1048.5',),
#  ('F9 B5 B1051.4',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1060.2 ',),
#  ('F9 B5 B1058.3 ',),
#  ('F9 B5 B1051.6',),
#  ('F9 B5 B1060.3',),
#  ('F9 B5 B1049.7 ',)]

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 4, 2) as month to get the months and substr(Date,7,4)='2015' for year.**

# %%
# %sql select Date, Landing_Outcome, BOOSTER_VERSION, LAUNCH_SITE from SPACEXTBL where (Landing_Outcome = 'Failure (drone ship)') and (substr(Date,7,4)='2015')
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order.

# %%
# %sql select Landing_Outcome, count(*) from SPACEXTBL where date between '2010-06-04' and '2017-03-20' group by (Landing_Outcome) order by count(*) desc
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('No attempt', 10),
#  ('Success (ground pad)', 5),
#  ('Success (drone ship)', 5),
#  ('Failure (drone ship)', 5),
#  ('Controlled (ocean)', 3),
#  ('Uncontrolled (ocean)', 2),
#  ('Precluded (drone ship)', 1),
#  ('Failure (parachute)', 1)]

# %% [markdown]
# ## Task 11
#
# display the mission outcome counts for each launch site

# %%
# %sql select  count("Mission_Outcome") as MISSION_OUTCOME_COUNT,Launch_Site  from SPACEXTBL group by "Launch_Site";
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(26, 'CCAFS LC-40'),
#  (34, 'CCAFS SLC-40'),
#  (25, 'KSC LC-39A'),
#  (16, 'VAFB SLC-4E')]

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
